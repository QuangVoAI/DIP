# %% [markdown]
# #**LAB 1: IMAGE FORMATION & COLOR SPACES**

# %% [markdown]
# **EXERCISES**
# - Getting Started
# - Reading and display an image in OpenCV using Python
# - Writing an image in OpenCV using Python
# Draw a text string
#
# 1.   Draw a line
# 2.   Draw arrow segment
# 3.  Draw an ellipse
# 4.  Draw a circle
# 5.  Draw a rectangle
# 6.  Color Spaces
# Code and run all the examples in the above instructions.

# %% [markdown]
# ### **Exercise 1: Reading and display an image in OpenCV using Python**

# %% [markdown]
# **Example 1.1 (Using OpenCV) :**

# %%
# Python code to read image
import cv2

# To read image from disk, we use
# cv2.imread function, in below method,
img = cv2.imread("image1_1.png", cv2.IMREAD_COLOR)

# Creating GUI window to display an image on screen
# first Parameter is windows title (should be in string format)
# Second Parameter is image array
cv2_imshow(img)

# To hold the window on screen, we use cv2.waitKey method
# Once it detected the close input, it will release the control
# To the next line
# First Parameter is for holding screen for specified milliseconds
# It should be positive integer. If 0 pass an parameter, then it will
# hold the screen until user close it.
cv2.waitKey(0)

# It is for removing/deleting created GUI window from screen
# and memory
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       6 img = cv2.imread("image1_1.png", cv2.IMREAD_COLOR)
#       8 # Creating GUI window to display an image on screen
#       9 # first Parameter is windows title (should be in string format)
#      10 # Second Parameter is image array
# ---> 11 cv2_imshow(img)
#      13 # To hold the window on screen, we use cv2.waitKey method
#      14 # Once it detected the close input, it will release the control
#      15 # To the next line
#      16 # First Parameter is for holding screen for specified milliseconds
#      17 # It should be positive integer. If 0 pass an parameter, then it will
#      18 # hold the screen until user close it.
#      19 cv2.waitKey(0)
#
# NameError: name 'cv2_imshow' is not defined

# %% [markdown]
# **Example 1.2: Note: See the difference in colors of images read by cv2 and matplotlib library. Because cv2 uses BGR color format and matplotlib uses RGB color format. To convert BGR to RGB, we us a function:**

# %%
#import cv2, numpy and matplotlib libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("image1_1.png")
#Displaying image using plt.imshow() method
plt.imshow(img)

#hold the window
plt.waitforbuttonpress()
plt.close('all')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3386833779.py in <cell line: 0>()
#       8
#       9 #hold the window
# ---> 10 plt.waitforbuttonpress()
#      11 plt.close('all')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in waitforbuttonpress(timeout)
#    2839 @_copy_docstring_and_deprecators(Figure.waitforbuttonpress)
#    2840 def waitforbuttonpress(timeout: float = -1) -> None | bool:
# -> 2841     return gcf().waitforbuttonpress(timeout=timeout)
#    2842
#    2843
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in waitforbuttonpress(self, timeout)
#    3601             self.canvas.stop_event_loop()
#    3602
# -> 3603         _blocking_input.blocking_input_loop(
#    3604             self, ["button_press_event", "key_press_event"], timeout, handler)
#    3605
#
# ...

# %% [markdown]
# **Example 1.3:**

# %%
#import cv2, numpy and matplotlib libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("image1_1.png")

# Converting BGR color to RGB color format
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Displaying image using plt.imshow() method
plt.imshow(RGB_img)

# hold the window
plt.waitforbuttonpress()
plt.close('all')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2131030303.py in <cell line: 0>()
#      12
#      13 # hold the window
# ---> 14 plt.waitforbuttonpress()
#      15 plt.close('all')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in waitforbuttonpress(timeout)
#    2839 @_copy_docstring_and_deprecators(Figure.waitforbuttonpress)
#    2840 def waitforbuttonpress(timeout: float = -1) -> None | bool:
# -> 2841     return gcf().waitforbuttonpress(timeout=timeout)
#    2842
#    2843
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in waitforbuttonpress(self, timeout)
#    3601             self.canvas.stop_event_loop()
#    3602
# -> 3603         _blocking_input.blocking_input_loop(
#    3604             self, ["button_press_event", "key_press_event"], timeout, handler)
#    3605
#
# ...

# %% [markdown]
# **Example 1.4: Opening in grayscale mode**

# %%
# Python program to explain cv2.imread() method

# importing cv2
import cv2

# path
path = r'image1_1.png'

# Using cv2.imread() method
# Using 0 to read image in grayscale mode
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

# Displaying the image
cv2_imshow(img) # Use cv2_imshow
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=200x141>

# %% [markdown]
# ### **Exercise 2: Writing an image in OpenCV using Python**

# %% [markdown]
# **Example 2.1:**

# %%
# Python program to explain cv2.imwrite() method

# importing cv2
import cv2

# importing os module
import os

# Image path (using the existing image from the notebook)
image_path = 'image1_1.png'

# Read the image
img = cv2.imread(image_path)

# Get the directory of the image
directory = os.path.dirname(image_path) or '.' # Use '.' if image_path is just a filename

# Change the current directory (optional, but good practice if saving elsewhere)
# os.chdir(directory) # Not necessary if saving in the current directory

# Filename for the saved image
filename = 'Example2_1.jpg'

# Using cv2.imwrite() method
# Saving the image
cv2.imwrite(filename, img)

# Verify the file is saved (optional)
print(f"Image saved as {filename}")
print("Files in the current directory:")
print(os.listdir('.'))
# Out:
# Image saved as Example2_1.jpg
# Files in the current directory:
# ['.config', '.ipynb_checkpoints', 'image3.png', 'Example2_1.jpg', 'image1_1.png', 'sample_parrot.jpeg', 'sample_data']

# %% [markdown]
# ### **Exercise 3: Draw A Text String**

# %% [markdown]
# **Example 3.1:**

# %%
# Python program to explain cv2.putText() method

# importing cv2
import cv2

# image_path
# Using image3.png as requested by the user
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {image_path}. Please make sure image3.png is uploaded to your Colab environment.")
else:
    # font
    font = cv2.FONT_HERSHEY_SIMPLEX

    # org
    org = (30, 50)

    # fontScale
    fontScale = 1

    # Blue color in BGR
    color = (255, 0, 0)

    # Line thickness of 2 px
    thickness = 2

    # Using cv2.putText() method
    image = cv2.putText(image, '523H0173', org, font,
                       fontScale, color, thickness, cv2.LINE_AA)

    # Displaying the image
    cv2_imshow(image) # Correct usage of cv2_imshow
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 3.2:**

# %%
# Python program to explain cv2.putText() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {image_path}. Please make sure image3.png is uploaded to your Colab environment.")
else:
    # Window name in which image is displayed
    # window_name = 'Image' # Not needed for cv2_imshow

    # text
    text = '523H0173'

    # font
    font = cv2.FONT_HERSHEY_SIMPLEX

    # org
    org = (30, 185)

    # fontScale
    fontScale = 1

    # Red color in BGR
    color = (0, 0, 255)

    # Line thickness of 2 px
    thickness = 2

    # Using cv2.putText() method (first call - likely a typo or leftover)
    image = cv2.putText(image, text, org, font, fontScale,
                      color, thickness, cv2.LINE_AA, False)

    # Using cv2.putText() method
    image = cv2.putText(image, text, org, font, fontScale,
                      color, thickness, cv2.LINE_AA, True) # Removed the last argument as it's not part of the standard function signature

    # Displaying the image
    cv2_imshow(image) # Removed window_name argument
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# ### **Exercise 4: Draw a line**

# %% [markdown]
# **Example 4.1:**

# %%
# Python program to explain cv2.line() method

import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

# Start coordinate, here (0, 0)
# represents the top left corner of image
start_point = (0, 0)

# End coordinate, here (250, 250)
# represents the bottom right corner of image
end_point = (250, 250)

# Green color in BGR
color = (0, 255, 0)

# Line thickness of 9 px
thickness = 9

# Using cv2.line() method
# Draw a diagonal green line with thickness of 9 px
image = cv2.line(image, start_point, end_point, color, thickness)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 4.2:**

# %%
# Python program to explain cv2.line() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in grayscale mode
image = cv2.imread(image_path, 0)

# Start coordinate, here (225, 0)
# represents the top right corner of image
start_point = (225, 0)

# End coordinate, here (0, 225)
# represents the bottom left corner of image
end_point = (0, 225)

# Black color in BGR
color = (0, 0, 0)

# Line thickness of 5 px
thickness = 5

# Using cv2.line() method
# Draw a diagonal black line with thickness of 5 px
image = cv2.line(image, start_point, end_point, color, thickness)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %% [markdown]
# **Example 4.3: Drawing a line on black screen using numpy library:**

# %%
import numpy as np
import cv2

# Creating a black screen image using numpy.zeros function
Img = np.zeros((512, 512, 3), dtype='uint8')

# Start coordinate, here (100, 100)
start_point = (100, 100)

# End coordinate, here (450, 450)
end_point = (450, 450)

# White color in BGR
color = (255, 250, 255)

# Line thickness of 9 px
thickness = 9

# Using cv2.line() method to draw a diagonal line
image = cv2.line(Img, start_point, end_point, color, thickness)

# Display the image in Colab
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### **Exercise 5: Draw Arrow Segment**

# %% [markdown]
# **Example 5.1:**

# %%
# Python program to explain cv2.arrowedLine() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

# Start coordinate, here (0, 0)
# represents the top left corner of image
start_point = (0, 0)

# End coordinate
end_point = (200, 200)

# Green color in BGR
color = (0, 255, 0)

# Line thickness of 9 px
thickness = 9

# Using cv2.arrowedLine() method
# Draw a diagonal green arrow line
# with thickness of 9 px
image = cv2.arrowedLine(image, start_point, end_point,
                                     color, thickness)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 5.2:**

# %%
# Python program to explain cv2.arrowedLine() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

# Start coordinate, here (225, 0)
# represents the top right corner of image
start_point = (225, 0)

# End coordinate
end_point = (0, 90)

# Red color in BGR
color = (0, 0, 255)

# Line thickness of 9 px
thickness = 9

# Using cv2.arrowedLine() method
# Draw a red arrow line
# with thickness of 9 px and tipLength = 0.5
image = cv2.arrowedLine(image, start_point, end_point,
                    color, thickness, tipLength = 0.5)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# ### **Exercise 6: Draw An Ellipse**

# %% [markdown]
# **Example 6.1:**

# %%
# Python program to explain cv2.ellipse() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

center_coordinates = (120, 100)

axesLength = (100, 50)

angle = 0

startAngle = 0

endAngle = 360

# Red color in BGR
color = (0, 0, 255)

# Line thickness of 5 px
thickness = 5

# Using cv2.ellipse() method
# Draw a ellipse with red line borders of thickness of 5 px
image = cv2.ellipse(image, center_coordinates, axesLength,
           angle, startAngle, endAngle, color, thickness)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 6.2: Using thickness of -1 px and rotation of 30 degrees**

# %%
# Python program to explain cv2.ellipse() method

# importing cv2
import cv2

# path
image_path = 'image3.png'

# Reading an image in default mode
image = cv2.imread(image_path)

center_coordinates = (120, 100)

axesLength = (100, 50)

angle = 30

startAngle = 0

endAngle = 360

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of -1 px
thickness = -1

# Using cv2.ellipse() method
# Draw a ellipse with blue line borders of thickness of -1 px
image = cv2.ellipse(image, center_coordinates, axesLength, angle,
                          startAngle, endAngle, color, thickness)

# Displaying the image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# ### **Exercise 7: Draw A Circle**

# %% [markdown]
# **Example:**

# %%
import cv2
from google.colab.patches import cv2_imshow

# Đọc ảnh
image_path = 'image3.png'
src = cv2.imread(image_path)

# Vẽ hình tròn
cv2.circle(src, center=(100, 100), radius=50, color=(0, 255, 0), thickness=2)

# Hiển thị ảnh
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 7.1: In this example, we draw a filled red circle on the image**

# %%
import cv2

image_path = 'image3.png'
src = cv2.imread(image_path)

cv2.circle(src, center=(150, 150), radius=40, color=(0, 0, 255), thickness=-1)

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 7.2: In this example, we draw multiple circles of different colors and sizes on the image**

# %%
import cv2

image_path= 'image3.png'
src = cv2.imread(image_path)

# Draw multiple circles
cv2.circle(src, center=(50, 50), radius=20, color=(255, 0, 0), thickness=3)  # Blue circle
cv2.circle(src, center=(200, 200), radius=30, color=(0, 255, 0), thickness=5)  # Green circle
cv2.circle(src, center=(300, 100), radius=40, color=(0, 0, 255), thickness=2)  # Red circle

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 7.3: In this example, we draw a large filled blue circle**

# %%
import cv2

image_path = 'image3.png'
src = cv2.imread(image_path)

cv2.circle(src, center=(250, 250), radius=60, color=(255, 0, 0), thickness=-1)  # Filled Blue Circle
cv2.circle(src, center=(250, 250), radius=60, color=(0, 255, 255), thickness=8) # Thick yellow outline

cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# ### **Exercise 8: Draw A Rectangel**

# %% [markdown]
# **Example 8.1: Drawing a Blue Rectangle Border**

# %%
import cv2

image = cv2.imread('image3.png')
cv2.rectangle(image, (5, 5), (220, 220), (255, 0, 0), 2)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %% [markdown]
# **Example 8.2: Drawing a Filled Black Rectangle on a Grayscale Image**

# %%
import cv2

image = cv2.imread(r'image3.png', 0)
cv2.rectangle(image, (100, 50), (125, 80), 0, -1)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %% [markdown]
# ### **Exercise 9: Color Spaces**

# %% [markdown]
# **Converting Between Color Spaces in OpenCV**

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('sample_parrot.jpeg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

cv2_imshow(image)
cv2_imshow(image_rgb)
cv2_imshow(image_hsv)
cv2_imshow(image_gray)
cv2_imshow(image_lab)
# Out:
# <PIL.Image.Image image mode=RGB size=228x399>
# <PIL.Image.Image image mode=RGB size=228x399>
# <PIL.Image.Image image mode=RGB size=228x399>
# <PIL.Image.Image image mode=L size=228x399>
# <PIL.Image.Image image mode=RGB size=228x399>

# %% [markdown]
# **Example 9.1: Detecting Red Color in an Image Using HSV**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow


image = cv2.imread('sample_parrot.jpeg')

image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_red = np.array([0, 120, 70])
upper_red = np.array([10, 255, 255])

mask = cv2.inRange(image_hsv, lower_red, upper_red)

result = cv2.bitwise_and(image, image, mask=mask)

cv2_imshow(result)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=228x399>

# %% [markdown]
# **Example 9.2: Visualizing the Different Color Channels of an RGB Image**

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('sample_parrot.jpeg')

B, G, R = cv2.split(image)
cv2_imshow(image)
cv2.waitKey(0)

cv2_imshow(B)
cv2.waitKey(0)

cv2_imshow(G)
cv2.waitKey(0)

cv2_imshow(R)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=228x399>
# <PIL.Image.Image image mode=L size=228x399>
# <PIL.Image.Image image mode=L size=228x399>
# <PIL.Image.Image image mode=L size=228x399>
